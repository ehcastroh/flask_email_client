# %% [markdown]
# <div align="center">
#     <img src= "/assets/content/datax_logos/DataX_blue_wide_logo.png" align="center" width="100%">
# </div>
#
# ### **HOMEWORK** 03 - **FLASK** DATABASE **DEPLOYMENT**
#
# <br>
#
# <div align="center" style="font-size:12px; font-family:FreeMono; font-weight: 100; font-stretch:ultra-condensed; line-height: 1.0; color:#2A2C2B">
#     <img src="/assets/content/images/flask_logo.png" align="center" width="20%" padding="10"><br>
#     <br>
# </div>
#
# <br>
#
# <br>
#
# In **m320_hw_1--flask_minimal_application** we introduced [**routing (decorators)**](https://flask.palletsprojects.com/en/1.1.x/api/#flask.Flask.route), the [**extends**](https://flask.palletsprojects.com/en/1.1.x/patterns/templateinheritance/) statement, and how to build a **Flask package**. The work on **m320_hw_2--flask_wtf** covered [**web forms** and **form validation**](https://flask.palletsprojects.com/en/1.1.x/patterns/wtforms/). This notebook covers Flask [**database server deployment**](https://flask.palletsprojects.com/en/1.1.x/deploying/#deployment), instead of the more barebones [**SQLite**](https://flask.palletsprojects.com/en/1.1.x/patterns/sqlite3/) disk-based database system used in the introductory coursework.
# <br>
#
# **Author list:** [Elias Casto Hernandez](https://www.linkedin.com/in/ehcastroh/)
#
# **References and Additional Resources**
# <br>
#
#
# > * [Flask by Example by Real Python](https://realpython.com/flask-by-example-part-1-project-setup/#project-setup)
#
# > * [Flask Mega Tutorial by Miguel Grinberg](https://courses.miguelgrinberg.com/courses/flask-mega-tutorial/lectures/5203689)
#
# > * [Flask Deployment Options](https://flask.palletsprojects.com/en/1.1.x/deploying/#deployment)

# %%
### Display videos in iframe within HTML ###
from IPython.display import HTML

HTML("""
    <table align="center" style="width:100%; font-size:22px; font-family:FreeMono; font-weight: 100; font-stretch:ultra-condensed; line-height: 1.2; color:#2A2C2B">
      <tr>
        <th>
            <!-- left column -->
            <div align="center" style="vertical-align:top">
                <strong>AWS TUTORIAL 1</strong>
            </div>
        </th> 
        <th>
            <!-- center column -->
            <div align="center" style="vertical-align:top">
                <strong>AWS TUTORIAL 2</strong>
            </div>
        </th> 
        <th>
            <!-- right column -->
            <div align="center" style="vertical-align:top">
                <strong>AWS TUTORIAL 3</strong>
            </div>
        </th> 
      </tr>
      <tr>
          <!-- left column -->
          <th style="font-size:16px; font-family:FreeMono; font-weight: 100; font-stretch:ultra-condensed; line-height: 1.2; color:#2A2C2B; vertical-align:top">  
              <div align="center" style="vertical-align:top">
                 <!-- EMBEDDED VIDEO -->
                  <iframe padding:10px width="100%"  height="250" src="https://www.youtube.com/embed/Xs0g_ZEv2bw?controls=1&start=12&autoplay=0&vq=hd1080" 
                          frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen>
                  </iframe>   
              </div>  
          </th>
          <!-- center column -->
          <th style="font-size:16px; font-family:FreeMono; font-weight: 100; font-stretch:ultra-condensed; line-height: 1.2; color:#2A2C2B; vertical-align:top">
              <div align="center">
                 <!-- EMBEDDED VIDEO -->
                  <iframe padding:10px width="100%" height="250" src="https://www.youtube.com/embed/tMC4h-arGPA?controls=1&start=12&autoplay=0&vq=hd1080" 
                          frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen>
                  </iframe> 
              </div>
          </th>
          <!-- right column -->
          <th style="font-size:16px; font-family:FreeMono; font-weight: 100; font-stretch:ultra-condensed; line-height: 1.2; color:#2A2C2B; vertical-align:top">  
              <div align="center" style="vertical-align:top">
                 <!-- EMBEDDED VIDEO -->
                  <iframe padding:10px width="100%" height="250" src="https://www.youtube.com/embed/z59TDrLSFx4?controls=1&start=12&autoplay=0&vq=hd1080" 
                          frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen>
                  </iframe> 
              </div>  
          </th>
      </tr>    
    </table>
    """)
# Out:
#     <table align="center" style="width:100%; font-size:22px; font-family:FreeMono; font-weight: 100; font-stretch:ultra-condensed; line-height: 1.2; color:#2A2C2B">
#       <tr>
#         <th>
#             <!-- left column -->
#             <div align="center" style="vertical-align:top">
#                 <strong>AWS TUTORIAL 1</strong>
#             </div>
#         </th>
#         <th>
#             <!-- center column -->
#             <div align="center" style="vertical-align:top">
#                 <strong>AWS TUTORIAL 2</strong>
#             </div>
#         </th>
#         <th>
#             <!-- right column -->
#             <div align="center" style="vertical-align:top">
#                 <strong>AWS TUTORIAL 3</strong>
#             </div>
#         </th>
#       </tr>
#       <tr>
#           <!-- left column -->
# ...

# %% [markdown]
# <br>
#
# 1) Watch **AWS TUTORIAL 1** and create your own EC2 Instance
#
# 2) Connect to server using SSH
#
# <br>
#
# #### **DELIVERABLES**
#
# Please submit the following:
# > (1) A picture of your AWS account (of browser with AWS open) once you've manually created your server.
#
# > (2) Initiate your server, and take a picture of your terminal after you've SSH'd into your server.
#
# <hr style="border: 1px solid#0B0B0B;" />
